# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
coordinates = list(zip(lats, lngs))

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 732

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port blair
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | airai
# Processing Record 4 of Set 1 | qaanaaq
# Processing Record 5 of Set 1 | hithadhoo
# Processing Record 6 of Set 1 | salalah
# Processing Record 7 of Set 1 | husavik
# Processing Record 8 of Set 1 | kibala
# Processing Record 9 of Set 1 | lasa
# Processing Record 10 of Set 1 | mar del plata
# Processing Record 11 of Set 1 | andenes
# Processing Record 12 of Set 1 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | sedelnikovo
# City not found. Skipping...
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | moron
# Processing Record 19 of Set 1 | san patricio
# Processing Record 20 of Set 1 | bengkulu
# Processing Record 21 of Set 1 | saint-philippe
# Processing Record 22 of Set 1 | chuy
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | nyurba
# Processing Record 25 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 26 of Set 1 | golkoy
# Processing Record 27 of Set 1 | broken hill
# Processing Record 28 of Set 1 | wanning
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | bambanglipuro
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | adrar
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | bambous virieux
# Processing Record 38 of Set 1 | leningradskiy
# Processing Record 39 of Set 1 | dabhol
# Processing Record 40 of Set 1 | east london
# Processing Record 41 of Set 1 | severo-kurilsk
# Processing Record 42 of Set 1 | bayji
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | tasiilaq
# Processing Record 45 of Set 1 | barrow
# Processing Record 46 of Set 1 | khvorostyanka
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | havoysund
# Processing Record 49 of Set 1 | carnarvon
# Processing Record 50 of Set 1 | faanui
# Processing Record 1 of Set 2 | hofn
# Processing Record 2 of Set 2 | boden
# Processing Record 3 of Set 2 | souillac
# Processing Record 4 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 2 | russell
# Processing Record 6 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | boralday
# Processing Record 9 of Set 2 | hasaki
# Processing Record 10 of Set 2 | beringovskiy
# Processing Record 11 of Set 2 | alaca
# Processing Record 12 of Set 2 | yeniseysk
# Processing Record 13 of Set 2 | biak
# Processing Record 14 of Set 2 | krasnoselkup
# Processing Record 15 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 2 | araouane
# Processing Record 17 of Set 2 | jalu
# Processing Record 18 of Set 2 | whitehorse
# Processing Record 19 of Set 2 | atuona
# Processing Record 20 of Set 2 | kapaa
# Processing Record 21 of Set 2 | thinadhoo
# Processing Record 22 of Set 2 | thompson
# Processing Record 23 of Set 2 | georgetown
# Processing Record 24 of Set 2 | tahoua
# Processing Record 25 of Set 2 | ternate
# Processing Record 26 of Set 2 | staraya poltavka
# Processing Record 27 of Set 2 | abatskoye
# Processing Record 28 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 2 | gimli
# Processing Record 30 of Set 2 | umm lajj
# Processing Record 31 of Set 2 | zhanatas
# City not found. Skipping...
# Processing Record 32 of Set 2 | richards bay
# Processing Record 33 of Set 2 | torbay
# Processing Record 34 of Set 2 | trincomalee
# Processing Record 35 of Set 2 | baruun-urt
# Processing Record 36 of Set 2 | pacific grove
# Processing Record 37 of Set 2 | ribeira grande
# Processing Record 38 of Set 2 | sitka
# Processing Record 39 of Set 2 | daru
# Processing Record 40 of Set 2 | constitucion
# Processing Record 41 of Set 2 | kodiak
# Processing Record 42 of Set 2 | bethel
# Processing Record 43 of Set 2 | lebu
# Processing Record 44 of Set 2 | masinigudi
# Processing Record 45 of Set 2 | moindou
# Processing Record 46 of Set 2 | dikson
# Processing Record 47 of Set 2 | touros
# Processing Record 48 of Set 2 | geraldton
# Processing Record 49 of Set 2 | pangody
# Processing Record 50 of Set 2 | kenai
# Processing Record 1 of Set 3 | hambantota
# Processing Record 2 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 3 of Set 3 | karratha
# Processing Record 4 of Set 3 | yulara
# Processing Record 5 of Set 3 | cayenne
# Processing Record 6 of Set 3 | ahipara
# Processing Record 7 of Set 3 | chokurdakh
# Processing Record 8 of Set 3 | narsaq
# Processing Record 9 of Set 3 | port elizabeth
# Processing Record 10 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 3 | bluff
# Processing Record 12 of Set 3 | pyapon
# Processing Record 13 of Set 3 | mount isa
# Processing Record 14 of Set 3 | isangel
# Processing Record 15 of Set 3 | cap malheureux
# Processing Record 16 of Set 3 | vardo
# Processing Record 17 of Set 3 | hilo
# Processing Record 18 of Set 3 | winslow
# Processing Record 19 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 3 | susanville
# Processing Record 21 of Set 3 | katsuura
# Processing Record 22 of Set 3 | tambilil
# Processing Record 23 of Set 3 | ponta do sol
# Processing Record 24 of Set 3 | zhangye
# Processing Record 25 of Set 3 | ancud
# Processing Record 26 of Set 3 | pisco
# Processing Record 27 of Set 3 | camden
# Processing Record 28 of Set 3 | obihiro
# Processing Record 29 of Set 3 | ilulissat
# Processing Record 30 of Set 3 | nikolskoye
# Processing Record 31 of Set 3 | tapaua
# City not found. Skipping...
# Processing Record 32 of Set 3 | fukue
# Processing Record 33 of Set 3 | pangnirtung
# Processing Record 34 of Set 3 | eau claire
# Processing Record 35 of Set 3 | staunton
# Processing Record 36 of Set 3 | puerto ayora
# Processing Record 37 of Set 3 | luderitz
# Processing Record 38 of Set 3 | toba tek singh
# Processing Record 39 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 3 | nanortalik
# Processing Record 41 of Set 3 | erenhot
# Processing Record 42 of Set 3 | kautokeino
# Processing Record 43 of Set 3 | grand gaube
# Processing Record 44 of Set 3 | khatanga
# Processing Record 45 of Set 3 | port alfred
# Processing Record 46 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 3 | hobyo
# Processing Record 48 of Set 3 | pasighat
# Processing Record 49 of Set 3 | victoria
# Processing Record 50 of Set 3 | port hedland
# Processing Record 1 of Set 4 | tezu
# Processing Record 2 of Set 4 | mocuba
# Processing Record 3 of Set 4 | tondano
# Processing Record 4 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 4 | lapua
# Processing Record 6 of Set 4 | castro
# Processing Record 7 of Set 4 | cabra
# Processing Record 8 of Set 4 | viedma
# Processing Record 9 of Set 4 | jumla
# Processing Record 10 of Set 4 | pinega
# Processing Record 11 of Set 4 | mae sai
# Processing Record 12 of Set 4 | aksarka
# Processing Record 13 of Set 4 | pochutla
# Processing Record 14 of Set 4 | klaksvik
# Processing Record 15 of Set 4 | vaini
# Processing Record 16 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 4 | veselynove
# Processing Record 18 of Set 4 | rabo de peixe
# Processing Record 19 of Set 4 | lensk
# Processing Record 20 of Set 4 | cabo san lucas
# Processing Record 21 of Set 4 | belaya gora
# Processing Record 22 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 4 | cornwall
# Processing Record 24 of Set 4 | siedlce
# Processing Record 25 of Set 4 | gao
# Processing Record 26 of Set 4 | burnie
# Processing Record 27 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 28 of Set 4 | sokolo
# Processing Record 29 of Set 4 | longyearbyen
# Processing Record 30 of Set 4 | arraial do cabo
# Processing Record 31 of Set 4 | leirvik
# Processing Record 32 of Set 4 | khani
# Processing Record 33 of Set 4 | yarim
# Processing Record 34 of Set 4 | washougal
# Processing Record 35 of Set 4 | hamilton
# Processing Record 36 of Set 4 | maneadero
# Processing Record 37 of Set 4 | padang
# Processing Record 38 of Set 4 | chilca
# Processing Record 39 of Set 4 | eregli
# Processing Record 40 of Set 4 | olinda
# Processing Record 41 of Set 4 | nome
# Processing Record 42 of Set 4 | broome
# Processing Record 43 of Set 4 | quatre cocos
# Processing Record 44 of Set 4 | kamenka
# Processing Record 45 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 4 | amapa
# Processing Record 47 of Set 4 | cidreira
# Processing Record 48 of Set 4 | inhambane
# Processing Record 49 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 4 | maralal
# Processing Record 1 of Set 5 | bassano
# Processing Record 2 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 5 | alofi
# Processing Record 4 of Set 5 | umea
# Processing Record 5 of Set 5 | avarua
# Processing Record 6 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 7 of Set 5 | rosarito
# Processing Record 8 of Set 5 | donji komren
# City not found. Skipping...
# Processing Record 9 of Set 5 | luwuk
# Processing Record 10 of Set 5 | ushtobe
# Processing Record 11 of Set 5 | marzuq
# Processing Record 12 of Set 5 | boulder city
# Processing Record 13 of Set 5 | bathsheba
# Processing Record 14 of Set 5 | cherskiy
# Processing Record 15 of Set 5 | kavieng
# Processing Record 16 of Set 5 | saint-augustin
# Processing Record 17 of Set 5 | hurghada
# Processing Record 18 of Set 5 | lompoc
# Processing Record 19 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 5 | nouadhibou
# Processing Record 21 of Set 5 | maloshuyka
# City not found. Skipping...
# Processing Record 22 of Set 5 | corn island
# Processing Record 23 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 5 | asfi
# Processing Record 25 of Set 5 | sofiysk
# City not found. Skipping...
# Processing Record 26 of Set 5 | port-de-bouc
# Processing Record 27 of Set 5 | kaitangata
# Processing Record 28 of Set 5 | chyhyryn
# Processing Record 29 of Set 5 | winona
# Processing Record 30 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 5 | ostrovnoy
# Processing Record 32 of Set 5 | dingle
# Processing Record 33 of Set 5 | dhidhdhoo
# Processing Record 34 of Set 5 | havre-saint-pierre
# Processing Record 35 of Set 5 | kruisfontein
# Processing Record 36 of Set 5 | bonfim
# Processing Record 37 of Set 5 | luanda
# Processing Record 38 of Set 5 | date
# Processing Record 39 of Set 5 | semey
# Processing Record 40 of Set 5 | matagami
# Processing Record 41 of Set 5 | upernavik
# Processing Record 42 of Set 5 | aranos
# Processing Record 43 of Set 5 | uray
# Processing Record 44 of Set 5 | odweyne
# Processing Record 45 of Set 5 | esperance
# Processing Record 46 of Set 5 | yerbogachen
# Processing Record 47 of Set 5 | acapulco
# Processing Record 48 of Set 5 | port hardy
# Processing Record 49 of Set 5 | dolinsk
# Processing Record 50 of Set 5 | turukhansk
# Processing Record 1 of Set 6 | mayahi
# Processing Record 2 of Set 6 | olafsvik
# Processing Record 3 of Set 6 | sivas
# Processing Record 4 of Set 6 | saint george
# Processing Record 5 of Set 6 | marsh harbour
# Processing Record 6 of Set 6 | dalvik
# Processing Record 7 of Set 6 | zhengjiatun
# Processing Record 8 of Set 6 | umm durman
# City not found. Skipping...
# Processing Record 9 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 10 of Set 6 | mayo
# Processing Record 11 of Set 6 | tuatapere
# Processing Record 12 of Set 6 | gat
# Processing Record 13 of Set 6 | udachnyy
# Processing Record 14 of Set 6 | mahebourg
# Processing Record 15 of Set 6 | harlingen
# Processing Record 16 of Set 6 | aykhal
# Processing Record 17 of Set 6 | shujaabad
# Processing Record 18 of Set 6 | lieksa
# Processing Record 19 of Set 6 | mahibadhoo
# Processing Record 20 of Set 6 | hualmay
# Processing Record 21 of Set 6 | dongsheng
# Processing Record 22 of Set 6 | vao
# Processing Record 23 of Set 6 | bandarbeyla
# Processing Record 24 of Set 6 | warmbad
# Processing Record 25 of Set 6 | wolbrom
# Processing Record 26 of Set 6 | mana
# Processing Record 27 of Set 6 | palmer
# Processing Record 28 of Set 6 | tiksi
# Processing Record 29 of Set 6 | saint-pierre
# Processing Record 30 of Set 6 | naze
# Processing Record 31 of Set 6 | kahului
# Processing Record 32 of Set 6 | nanma
# Processing Record 33 of Set 6 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 34 of Set 6 | ventersburg
# Processing Record 35 of Set 6 | morondava
# Processing Record 36 of Set 6 | payakumbuh
# Processing Record 37 of Set 6 | portland
# Processing Record 38 of Set 6 | shache
# Processing Record 39 of Set 6 | kango
# Processing Record 40 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 41 of Set 6 | ashtabula
# Processing Record 42 of Set 6 | vila franca do campo
# Processing Record 43 of Set 6 | lorengau
# Processing Record 44 of Set 6 | kalmunai
# Processing Record 45 of Set 6 | la serena
# Processing Record 46 of Set 6 | manaus
# Processing Record 47 of Set 6 | abu samrah
# Processing Record 48 of Set 6 | kloulklubed
# Processing Record 49 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 50 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 1 of Set 7 | saskylakh
# Processing Record 2 of Set 7 | panaba
# Processing Record 3 of Set 7 | cajamarca
# Processing Record 4 of Set 7 | flinders
# Processing Record 5 of Set 7 | balabac
# Processing Record 6 of Set 7 | tuktoyaktuk
# Processing Record 7 of Set 7 | ambon
# Processing Record 8 of Set 7 | havelock
# Processing Record 9 of Set 7 | ambilobe
# Processing Record 10 of Set 7 | aklavik
# Processing Record 11 of Set 7 | kapit
# Processing Record 12 of Set 7 | goderich
# Processing Record 13 of Set 7 | lahijan
# Processing Record 14 of Set 7 | jeremie
# Processing Record 15 of Set 7 | pevek
# Processing Record 16 of Set 7 | tibati
# Processing Record 17 of Set 7 | cabedelo
# Processing Record 18 of Set 7 | borogontsy
# Processing Record 19 of Set 7 | gull lake
# Processing Record 20 of Set 7 | apartado
# Processing Record 21 of Set 7 | mopipi
# Processing Record 22 of Set 7 | buraydah
# Processing Record 23 of Set 7 | fairbanks
# Processing Record 24 of Set 7 | makakilo city
# Processing Record 25 of Set 7 | valparaiso
# Processing Record 26 of Set 7 | shangzhi
# Processing Record 27 of Set 7 | parrita
# Processing Record 28 of Set 7 | seoul
# Processing Record 29 of Set 7 | shiraoi
# Processing Record 30 of Set 7 | nichinan
# Processing Record 31 of Set 7 | linhares
# Processing Record 32 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 33 of Set 7 | sangar
# Processing Record 34 of Set 7 | sibu
# Processing Record 35 of Set 7 | vanimo
# Processing Record 36 of Set 7 | kahta
# Processing Record 37 of Set 7 | opuwo
# Processing Record 38 of Set 7 | lagoa
# Processing Record 39 of Set 7 | labuhan
# Processing Record 40 of Set 7 | pandan
# Processing Record 41 of Set 7 | saldanha
# Processing Record 42 of Set 7 | ixtapa
# Processing Record 43 of Set 7 | serebryanyy bor
# Processing Record 44 of Set 7 | presidencia roque saenz pena
# Processing Record 45 of Set 7 | taltal
# Processing Record 46 of Set 7 | tautira
# Processing Record 47 of Set 7 | maua
# Processing Record 48 of Set 7 | nhulunbuy
# Processing Record 49 of Set 7 | menongue
# Processing Record 50 of Set 7 | navoi
# Processing Record 1 of Set 8 | aasiaat
# Processing Record 2 of Set 8 | baker city
# Processing Record 3 of Set 8 | norman wells
# Processing Record 4 of Set 8 | helsinki
# Processing Record 5 of Set 8 | mandurah
# Processing Record 6 of Set 8 | cairo
# Processing Record 7 of Set 8 | te anau
# Processing Record 8 of Set 8 | polis
# Processing Record 9 of Set 8 | kungurtug
# Processing Record 10 of Set 8 | griffith
# Processing Record 11 of Set 8 | yar-sale
# Processing Record 12 of Set 8 | dolores
# Processing Record 13 of Set 8 | lavrentiya
# Processing Record 14 of Set 8 | baracoa
# Processing Record 15 of Set 8 | bubaque
# Processing Record 16 of Set 8 | aguimes
# Processing Record 17 of Set 8 | glendive
# Processing Record 18 of Set 8 | yurino
# Processing Record 19 of Set 8 | hochheim
# Processing Record 20 of Set 8 | hami
# Processing Record 21 of Set 8 | yatou
# Processing Record 22 of Set 8 | luceville
# City not found. Skipping...
# Processing Record 23 of Set 8 | henties bay
# Processing Record 24 of Set 8 | mbeya
# Processing Record 25 of Set 8 | cuxhaven
# Processing Record 26 of Set 8 | maarianhamina
# Processing Record 27 of Set 8 | liverpool
# Processing Record 28 of Set 8 | almeirim
# Processing Record 29 of Set 8 | messina
# Processing Record 30 of Set 8 | bodden town
# Processing Record 31 of Set 8 | lagos
# Processing Record 32 of Set 8 | charyshskoye
# Processing Record 33 of Set 8 | manavalakurichi
# Processing Record 34 of Set 8 | winnemucca
# Processing Record 35 of Set 8 | saint-francois
# Processing Record 36 of Set 8 | burlington
# Processing Record 37 of Set 8 | ko samui
# Processing Record 38 of Set 8 | merauke
# Processing Record 39 of Set 8 | gaptsakh
# Processing Record 40 of Set 8 | alyangula
# Processing Record 41 of Set 8 | nelson bay
# Processing Record 42 of Set 8 | arman
# Processing Record 43 of Set 8 | puertollano
# Processing Record 44 of Set 8 | sao filipe
# Processing Record 45 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 8 | mackenzie
# Processing Record 47 of Set 8 | sterling
# Processing Record 48 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 49 of Set 8 | coquimbo
# Processing Record 50 of Set 8 | los alamos
# Processing Record 1 of Set 9 | port macquarie
# Processing Record 2 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 3 of Set 9 | linguere
# Processing Record 4 of Set 9 | diffa
# Processing Record 5 of Set 9 | san juan
# Processing Record 6 of Set 9 | chipurupalle
# Processing Record 7 of Set 9 | saint-leu
# Processing Record 8 of Set 9 | duku
# Processing Record 9 of Set 9 | plettenberg bay
# Processing Record 10 of Set 9 | manta
# Processing Record 11 of Set 9 | haines junction
# Processing Record 12 of Set 9 | fortuna
# Processing Record 13 of Set 9 | zhangzhou
# Processing Record 14 of Set 9 | chernenko
# Processing Record 15 of Set 9 | lufilufi
# Processing Record 16 of Set 9 | morro bay
# Processing Record 17 of Set 9 | maridi
# Processing Record 18 of Set 9 | caceres
# Processing Record 19 of Set 9 | anadyr
# Processing Record 20 of Set 9 | deoria
# Processing Record 21 of Set 9 | finschhafen
# Processing Record 22 of Set 9 | columbia
# Processing Record 23 of Set 9 | jieshi
# Processing Record 24 of Set 9 | rawson
# Processing Record 25 of Set 9 | kalispell
# Processing Record 26 of Set 9 | bocas del toro
# Processing Record 27 of Set 9 | oktyabrskiy
# Processing Record 28 of Set 9 | dusetos
# Processing Record 29 of Set 9 | kudahuvadhoo
# Processing Record 30 of Set 9 | saint pete beach
# Processing Record 31 of Set 9 | komsomolskiy
# Processing Record 32 of Set 9 | mount pleasant
# Processing Record 33 of Set 9 | mnogovershinnyy
# Processing Record 34 of Set 9 | vila
# Processing Record 35 of Set 9 | oussouye
# Processing Record 36 of Set 9 | sakakah
# Processing Record 37 of Set 9 | guozhen
# Processing Record 38 of Set 9 | lityn
# Processing Record 39 of Set 9 | vanderhoof
# Processing Record 40 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 9 | duz
# City not found. Skipping...
# Processing Record 42 of Set 9 | catuday
# Processing Record 43 of Set 9 | samarai
# Processing Record 44 of Set 9 | ballina
# Processing Record 45 of Set 9 | otacilio costa
# Processing Record 46 of Set 9 | valkeakoski
# Processing Record 47 of Set 9 | muncie
# Processing Record 48 of Set 9 | roma
# Processing Record 49 of Set 9 | riyadh
# Processing Record 50 of Set 9 | luoyang
# Processing Record 1 of Set 10 | los llanos de aridane
# Processing Record 2 of Set 10 | bokaro
# Processing Record 3 of Set 10 | iqaluit
# Processing Record 4 of Set 10 | honiara
# Processing Record 5 of Set 10 | marawi
# Processing Record 6 of Set 10 | mount gambier
# Processing Record 7 of Set 10 | ugoofaaru
# Processing Record 8 of Set 10 | ponta delgada
# Processing Record 9 of Set 10 | suzaka
# Processing Record 10 of Set 10 | ust-tsilma
# Processing Record 11 of Set 10 | auki
# Processing Record 12 of Set 10 | kinablangan
# Processing Record 13 of Set 10 | vostok
# Processing Record 14 of Set 10 | raudeberg
# Processing Record 15 of Set 10 | kidal
# Processing Record 16 of Set 10 | ipora
# Processing Record 17 of Set 10 | yomitan
# City not found. Skipping...
# Processing Record 18 of Set 10 | san cristobal
# Processing Record 19 of Set 10 | miranorte
# City not found. Skipping...
# Processing Record 20 of Set 10 | itarema
# Processing Record 21 of Set 10 | ola
# Processing Record 22 of Set 10 | shenjiamen
# Processing Record 23 of Set 10 | kendari
# Processing Record 24 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 25 of Set 10 | asau
# Processing Record 26 of Set 10 | okha
# Processing Record 27 of Set 10 | jasper
# Processing Record 28 of Set 10 | yenagoa
# Processing Record 29 of Set 10 | zyryanka
# Processing Record 30 of Set 10 | tokat
# Processing Record 31 of Set 10 | gisborne
# Processing Record 32 of Set 10 | xining
# Processing Record 33 of Set 10 | revda
# Processing Record 34 of Set 10 | atambua
# Processing Record 35 of Set 10 | horsham
# Processing Record 36 of Set 10 | baiersbronn
# Processing Record 37 of Set 10 | maragogi
# Processing Record 38 of Set 10 | bereda
# Processing Record 39 of Set 10 | viseu
# Processing Record 40 of Set 10 | clyde river
# Processing Record 41 of Set 10 | nadym
# Processing Record 42 of Set 10 | kiama
# Processing Record 43 of Set 10 | shamary
# Processing Record 44 of Set 10 | karasburg
# Processing Record 45 of Set 10 | eskisehir
# Processing Record 46 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 10 | fria
# Processing Record 48 of Set 10 | mbandaka
# Processing Record 49 of Set 10 | erzin
# Processing Record 50 of Set 10 | sirsa
# Processing Record 1 of Set 11 | noumea
# Processing Record 2 of Set 11 | altamira
# Processing Record 3 of Set 11 | kokstad
# Processing Record 4 of Set 11 | pompeu
# Processing Record 5 of Set 11 | kinshasa
# Processing Record 6 of Set 11 | baiyin
# Processing Record 7 of Set 11 | lincoln
# Processing Record 8 of Set 11 | diamantino
# Processing Record 9 of Set 11 | znamenskoye
# Processing Record 10 of Set 11 | chipinge
# Processing Record 11 of Set 11 | puerto escondido
# Processing Record 12 of Set 11 | caravelas
# Processing Record 13 of Set 11 | kesennuma
# City not found. Skipping...
# Processing Record 14 of Set 11 | worland
# Processing Record 15 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 11 | tifton
# Processing Record 17 of Set 11 | cerro gordo
# Processing Record 18 of Set 11 | hokitika
# Processing Record 19 of Set 11 | bilma
# Processing Record 20 of Set 11 | tomatlan
# Processing Record 21 of Set 11 | lake charles
# Processing Record 22 of Set 11 | kawanishi
# Processing Record 23 of Set 11 | sao miguel do araguaia
# Processing Record 24 of Set 11 | markova
# Processing Record 25 of Set 11 | gien
# Processing Record 26 of Set 11 | puerto suarez
# Processing Record 27 of Set 11 | haputale
# Processing Record 28 of Set 11 | graciano sanchez
# Processing Record 29 of Set 11 | byron bay
# Processing Record 30 of Set 11 | vuktyl
# Processing Record 31 of Set 11 | sambava
# Processing Record 32 of Set 11 | penzance
# Processing Record 33 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 11 | codrington
# Processing Record 35 of Set 11 | liebenburg
# Processing Record 36 of Set 11 | nemuro
# Processing Record 37 of Set 11 | verkhoyansk
# Processing Record 38 of Set 11 | orlik
# Processing Record 39 of Set 11 | lang son
# Processing Record 40 of Set 11 | san jose
# Processing Record 41 of Set 11 | kavaratti
# Processing Record 42 of Set 11 | saint-joseph
# Processing Record 43 of Set 11 | cockburn town
# Processing Record 44 of Set 11 | dalby
# Processing Record 45 of Set 11 | saint john
# Processing Record 46 of Set 11 | swift current
# Processing Record 47 of Set 11 | plymouth
# Processing Record 48 of Set 11 | yuci
# Processing Record 49 of Set 11 | dawei
# Processing Record 50 of Set 11 | huanren
# Processing Record 1 of Set 12 | mathbaria
# Processing Record 2 of Set 12 | talas
# Processing Record 3 of Set 12 | mogadishu
# Processing Record 4 of Set 12 | avera
# Processing Record 5 of Set 12 | eydhafushi
# Processing Record 6 of Set 12 | mandal
# Processing Record 7 of Set 12 | vengerovo
# Processing Record 8 of Set 12 | el alto
# Processing Record 9 of Set 12 | provideniya
# Processing Record 10 of Set 12 | ulladulla
# Processing Record 11 of Set 12 | elko
# Processing Record 12 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 13 of Set 12 | lewistown
# Processing Record 14 of Set 12 | uuemoisa
# Processing Record 15 of Set 12 | talnakh
# Processing Record 16 of Set 12 | taunggyi
# Processing Record 17 of Set 12 | niksar
# Processing Record 18 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 19 of Set 12 | sioux lookout
# Processing Record 20 of Set 12 | medea
# Processing Record 21 of Set 12 | kaeo
# Processing Record 22 of Set 12 | kalininsk
# Processing Record 23 of Set 12 | ossora
# Processing Record 24 of Set 12 | baoying
# Processing Record 25 of Set 12 | heyang
# Processing Record 26 of Set 12 | ashland
# Processing Record 27 of Set 12 | mae hong son
# Processing Record 28 of Set 12 | ripoll
# Processing Record 29 of Set 12 | sisimiut
# Processing Record 30 of Set 12 | kasimov
# Processing Record 31 of Set 12 | vilhena
# Processing Record 32 of Set 12 | pacaembu
# Processing Record 33 of Set 12 | sobolevo
# Processing Record 34 of Set 12 | houma
# Processing Record 35 of Set 12 | salina cruz
# Processing Record 36 of Set 12 | alappuzha
# Processing Record 37 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 38 of Set 12 | papasquiaro
# City not found. Skipping...
# Processing Record 39 of Set 12 | kirakira
# Processing Record 40 of Set 12 | suntar
# Processing Record 41 of Set 12 | gunnedah
# Processing Record 42 of Set 12 | beidao
# Processing Record 43 of Set 12 | sande
# Processing Record 44 of Set 12 | san policarpo
# Processing Record 45 of Set 12 | mattru
# Processing Record 46 of Set 12 | moscow
# Processing Record 47 of Set 12 | port lincoln
# Processing Record 48 of Set 12 | fort pierce
# Processing Record 49 of Set 12 | pingliang
# Processing Record 50 of Set 12 | doka
# Processing Record 1 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 2 of Set 13 | gari
# Processing Record 3 of Set 13 | sinnamary
# Processing Record 4 of Set 13 | tabuk
# Processing Record 5 of Set 13 | yuzhnyy
# Processing Record 6 of Set 13 | khania
# City not found. Skipping...
# Processing Record 7 of Set 13 | solton
# Processing Record 8 of Set 13 | touho
# Processing Record 9 of Set 13 | shkotovo-22
# City not found. Skipping...
# Processing Record 10 of Set 13 | yermakovskoye
# Processing Record 11 of Set 13 | santa cruz cabralia
# Processing Record 12 of Set 13 | cozumel
# Processing Record 13 of Set 13 | vizinga
# Processing Record 14 of Set 13 | haldia
# Processing Record 15 of Set 13 | pasni
# Processing Record 16 of Set 13 | oyama
# Processing Record 17 of Set 13 | porto walter
# Processing Record 18 of Set 13 | kutum
# Processing Record 19 of Set 13 | comodoro rivadavia
# Processing Record 20 of Set 13 | flin flon
# Processing Record 21 of Set 13 | inirida
# Processing Record 22 of Set 13 | grafton
# Processing Record 23 of Set 13 | barcelos
# Processing Record 24 of Set 13 | zhicheng
# Processing Record 25 of Set 13 | pedro ii
# Processing Record 26 of Set 13 | tiruchchendur
# Processing Record 27 of Set 13 | mugla
# Processing Record 28 of Set 13 | magadi
# Processing Record 29 of Set 13 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 30 of Set 13 | hovd
# Processing Record 31 of Set 13 | sinjhoro
# Processing Record 32 of Set 13 | algeciras
# Processing Record 33 of Set 13 | banda aceh
# Processing Record 34 of Set 13 | denpasar
# Processing Record 35 of Set 13 | northam
# Processing Record 36 of Set 13 | golspie
# Processing Record 37 of Set 13 | north platte
# Processing Record 38 of Set 13 | gulu
# Processing Record 39 of Set 13 | dir
# Processing Record 40 of Set 13 | alta floresta
# Processing Record 41 of Set 13 | kieta
# Processing Record 42 of Set 13 | virginia beach
# Processing Record 43 of Set 13 | aksu
# Processing Record 44 of Set 13 | atar
# Processing Record 45 of Set 13 | sheridan
# Processing Record 46 of Set 13 | smithers
# Processing Record 47 of Set 13 | taoudenni
# Processing Record 48 of Set 13 | govindgarh
# Processing Record 49 of Set 13 | dibaya
# City not found. Skipping...
# Processing Record 50 of Set 13 | eyl
# Processing Record 1 of Set 14 | waddan
# Processing Record 2 of Set 14 | raton
# Processing Record 3 of Set 14 | puerto leguizamo
# Processing Record 4 of Set 14 | santiago del estero
# Processing Record 5 of Set 14 | korablino
# Processing Record 6 of Set 14 | umm kaddadah
# Processing Record 7 of Set 14 | saint-cesaire
# Processing Record 8 of Set 14 | ajdabiya
# Processing Record 9 of Set 14 | poshekhonye
# Processing Record 10 of Set 14 | grindavik
# Processing Record 11 of Set 14 | oum hadjer
# Processing Record 12 of Set 14 | rubiataba
# Processing Record 13 of Set 14 | west bay
# Processing Record 14 of Set 14 | shakawe
# Processing Record 15 of Set 14 | tyazhinskiy
# Processing Record 16 of Set 14 | port augusta
# Processing Record 17 of Set 14 | dwarka
# Processing Record 18 of Set 14 | moyobamba
# Processing Record 19 of Set 14 | sao joao da barra
# Processing Record 20 of Set 14 | sauda
# Processing Record 21 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 14 | hays
# Processing Record 23 of Set 14 | sibolga
# Processing Record 24 of Set 14 | vrangel
# Processing Record 25 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 26 of Set 14 | yeppoon
# Processing Record 27 of Set 14 | nara
# Processing Record 28 of Set 14 | milingimbi
# City not found. Skipping...
# Processing Record 29 of Set 14 | saint anthony
# Processing Record 30 of Set 14 | tuchola
# Processing Record 31 of Set 14 | nybro
# Processing Record 32 of Set 14 | maceio
# Processing Record 33 of Set 14 | sihora
# Processing Record 34 of Set 14 | iquique
# Processing Record 35 of Set 14 | camacha
# Processing Record 36 of Set 14 | tymovskoye
# Processing Record 37 of Set 14 | bako
# Processing Record 38 of Set 14 | tual
# Processing Record 39 of Set 14 | katobu
# Processing Record 40 of Set 14 | soyo
# Processing Record 41 of Set 14 | margate
# Processing Record 42 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 43 of Set 14 | orumiyeh
# Processing Record 44 of Set 14 | chimbote
# Processing Record 45 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 46 of Set 14 | korla
# Processing Record 47 of Set 14 | sikonge
# Processing Record 48 of Set 14 | balkhash
# Processing Record 49 of Set 14 | tooele
# Processing Record 50 of Set 14 | tiarei
# Processing Record 1 of Set 15 | naftah
# City not found. Skipping...
# Processing Record 2 of Set 15 | kabompo
# Processing Record 3 of Set 15 | manuk mangkaw
# Processing Record 4 of Set 15 | sayyan
# Processing Record 5 of Set 15 | toucheng
# Processing Record 6 of Set 15 | lomovka
# Processing Record 7 of Set 15 | resistencia
# Processing Record 8 of Set 15 | samandag
# Processing Record 9 of Set 15 | taos
# Processing Record 10 of Set 15 | cotonou
# Processing Record 11 of Set 15 | alekseyevskoye
# Processing Record 12 of Set 15 | pimentel
# Processing Record 13 of Set 15 | nizhniy kuranakh
# Processing Record 14 of Set 15 | boffa
# Processing Record 15 of Set 15 | konongo
# Processing Record 16 of Set 15 | guadalupe y calvo
# Processing Record 17 of Set 15 | goalpara
# Processing Record 18 of Set 15 | kharp
# Processing Record 19 of Set 15 | bundaberg
# Processing Record 20 of Set 15 | bontang
# Processing Record 21 of Set 15 | bajil
# Processing Record 22 of Set 15 | royan
# Processing Record 23 of Set 15 | pemba
# Processing Record 24 of Set 15 | anchorage
# Processing Record 25 of Set 15 | college
# Processing Record 26 of Set 15 | chara
# Processing Record 27 of Set 15 | pithoragarh
# Processing Record 28 of Set 15 | acajutla
# Processing Record 29 of Set 15 | la mana
# Processing Record 30 of Set 15 | shahr-e kord
# Processing Record 31 of Set 15 | buritis
# Processing Record 32 of Set 15 | alotau
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Port Blair  11.6667   92.7500     84.04        73          89
# 1   Punta Arenas -53.1500  -70.9167     50.11        71          75
# 2          Airai  -8.9266  125.4092     80.67        43          89
# 3        Qaanaaq  77.4840  -69.3632     14.83        78          71
# 4      Hithadhoo  -0.6000   73.0833     83.32        73          93
# 5        Salalah  17.0151   54.0924     78.89        65          20
# 6        Husavik  66.0449  -17.3389     39.11        98         100
# 7         Kibala   9.1104   18.3463     75.15        88           0
# 8           Lasa  46.6166   10.7002     40.08        55          80
# 9  Mar Del Plata -38.0023  -57.5575     63.88        89           0
#
#    Wind Speed Country Current Description
# 0       12.91      IN     overcast clouds
# 1       11.50      CL       broken clouds
# 2        2.46      TL     overcast clouds
# 3        7.52      GL       broken clouds
# 4       13.29      MV     overcast clouds
# 5        4.61      OM          few clouds
# 6       22.64      IS          light rain
# 7        0.00      TD           clear sky
# 8        4.14      IT       broken clouds
# 9        5.99      AR           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
